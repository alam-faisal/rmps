# %%
import sys
sys.path.insert(0, '/Users/alam/code/rmps/')

from rmps_purity import *
from scipy.stats import linregress
import matplotlib.pyplot as plt
import scienceplots
from tqdm.notebook import tqdm

np.set_printoptions(precision=3, threshold=np.inf, suppress=True)

# %%
def process_data(data, n_list, k_copies, batch_size=1000, ti=False): 
    num_samples = data.shape[1]
    num_batches = int(num_samples//batch_size)
    
    h_purity = [haar_purity(n, k_copies, scaled=True, ti=ti) for n in n_list]
    
    err_mean = []
    err_std = []
    actual_n_list = []
    for i in range(len(data)):
        batches = [data[i,j*batch_size:(j+1)*batch_size] for j in range(num_batches)]
        purities = [samples_to_purity(batch, k_copies) for batch in batches]
        diff = np.array([p-h_purity[i] for p in purities])
        if np.all(diff > 0.0):
            one_err = np.sqrt(diff)
            err_mean.append(np.mean(one_err))
            err_std.append(np.std(one_err))
            actual_n_list.append(n_list[i])
    return err_mean, err_std, np.array(actual_n_list)

def set_style():
    plt.style.use(['science', 'grid', 'no-latex'])
    plt.rcParams['image.cmap'] = 'cividis'
    
    plt.rcParams['axes.labelsize'] = 8 
    plt.rcParams['xtick.labelsize'] = 8  
    plt.rcParams['ytick.labelsize'] = 8 
    plt.rcParams['legend.fontsize'] = 8 
    plt.rcParams['lines.linewidth'] = 1.5
    plt.rcParams['savefig.dpi'] = 300
    plt.rcParams['figure.dpi'] = 300 
    
    plt.rcParams['axes.titlesize'] = 10
    
    plt.rcParams['axes.grid'] = True  
    plt.rcParams['axes.spines.top'] = True 
    plt.rcParams['axes.spines.right'] = True

# %% [markdown]
# # Run Oct 12th

# %% [markdown]
# ## Open $\chi = n$

# %%
with open("open_linear.pickle", "rb") as f: 
    data = pickle.load(f)

# %%
n_list = np.arange(4, 50+1, 2)
k_copies = 2
err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=50000)
plt.plot(n_list, err_mean)
plt.plot(n_list, 0.5+n_list**(-1/4))
#plt.ylim(0,2.5)

# %% [markdown]
# ## Open $\chi\in [8,10,12,14,16,20,24,28,32]$

# %%
chi_list = [8,10,12,14,16,20,24,28,32]

data_array = []
for chi in chi_list:
    with open(f"open_{chi}.pickle", "rb") as f: 
        data_array.append(pickle.load(f))

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.1, 0.9, len(chi_list)))

err_mean_array = []
n_array = []
k_copies = 2  

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    plt.plot(n_list, err_mean, label=f'$\chi$ = {chi}', color=color)
#plt.legend()
plt.ylabel(r'upper bound on 1-norm error')
plt.xlabel('system size') 
plt.title(f"$k={k_copies}$")
plt.savefig("obc_plot-1.pdf", format="pdf", bbox_inches="tight")

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.2, 0.8, len(chi_list)))

two_norm_against_n = []
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    h_purities = [2**(n*k_copies/2) for n in n_list]
    two_norm_errs = [err/h for (err,h) in zip(err_mean,h_purities)]
    two_norm_against_n.append(two_norm_errs)
    plt.plot(n_list[:14], two_norm_errs[:14], label=f'$\chi = {chi}$', color=color)
    
plt.ylabel(r'2-norm error')
plt.xlabel('system size') 
plt.title(f"$k={k_copies}$")
plt.yscale('log')
#plt.legend()
plt.savefig("obc_plot1.pdf", format="pdf", bbox_inches="tight")

# %%
err_mean_array = []
n_array = []
k_copies = 2

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)

slope_list2 = []
intercept_list2 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list2.append(result.slope)
    intercept_list2.append(result.intercept)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.008399020073216357
# 1-r = 0.042750395985020395
# 1-r = 0.019821815831335465
# 1-r = 0.036438458477271896
# 1-r = 0.029028806931109652
# 1-r = 0.04583324561412949
# 1-r = 0.0854904297829806
# 1-r = 0.12298901396298911
# 1-r = 0.11633863255997756

# %%
err_mean_array = []
n_array = []
k_copies = 3

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list3 = []
intercept_list3 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list3.append(result.slope)
    intercept_list3.append(result.intercept)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.026362820297584744
# 1-r = 0.049447258302113495
# 1-r = 0.019219563716701082
# 1-r = 0.07429185101083946
# 1-r = 0.041602688017465805
# 1-r = 0.05782493663123367
# 1-r = 0.07908311408714241
# 1-r = 0.12794767386227734
# 1-r = 0.13626041415724055

# %%
err_mean_array = []
n_array = []
k_copies = 4

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list4 = []
intercept_list4 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list4.append(result.slope)
    intercept_list4.append(result.intercept)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.10890085560940033
# 1-r = 0.07002928506869877
# 1-r = 0.024989969003098245
# 1-r = 0.16747145680004916
# 1-r = 0.08915224935347033
# 1-r = 0.10578207482002178
# 1-r = 0.12908670601769012
# 1-r = 0.17530576078361992
# 1-r = 0.25492832201222493

# %%
err_mean_array = []
n_array = []
k_copies = 5

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list5 = []
intercept_list5 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list5.append(result.slope)
    intercept_list5.append(result.intercept)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.24020911239129294
# 1-r = 0.10435924314492839
# 1-r = 0.03626184080895989
# 1-r = 0.283534318901161
# 1-r = 0.17593745111669845
# 1-r = 0.17254235153911335
# 1-r = 0.23094814327590452
# 1-r = 0.265237939632209
# 1-r = 0.4244560459285879

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.25, 0.75, 4))

plt.plot(np.array(chi_list), slope_list2, '-o', label='$k=2$', color=colors[0], markersize=3)
plt.plot(np.array(chi_list), slope_list3, '-o', label='$k=3$', color=colors[1], markersize=3)
plt.plot(np.array(chi_list), slope_list4, '-o', label='$k=4$', color=colors[2], markersize=3)
plt.plot(np.array(chi_list), slope_list5, '-o', label='$k=5$', color=colors[3], markersize=3)
plt.plot(np.array(chi_list), 1/(np.array(chi_list)**2), '--', label=r"$1/\chi^2$", color='k')
plt.yscale('log')
plt.xscale('log')
plt.ylabel(r'decay rate')
plt.xlabel(r'bond dimension')

legend_elements = [
    plt.Line2D([0], [0], color=colors[0], marker='o', linestyle='-', label='$k=2$'),
    plt.Line2D([0], [0], color=colors[1], marker='o', linestyle='-', label='$k=3$'),
    plt.Line2D([0], [0], color=colors[2], marker='o', linestyle='-', label='$k=4$'),
    plt.Line2D([0], [0], color=colors[3], marker='o', linestyle='-', label='$k=5$'),
    plt.Line2D([0], [0], color='k', marker=None, linestyle='--', label=r"$1/\chi^2$")
]

plt.legend(handles=legend_elements, loc="upper center", ncol=5, bbox_to_anchor=(0.5, 1.3))

plt.savefig("obc_plot2.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# # Run Oct 18th

# %% [markdown]
# ## Periodic $\chi\in [4,8,10,12,14,16,20,24,28,32]$

# %%
#chi_list = [4,8,10,12,14,16,20,24,28,32]
chi_list = [4,8,10,12,16]
data_array = []
for chi in chi_list:
    with open(f"periodic_{chi}.pickle", "rb") as f: 
        data_array.append(pickle.load(f))

# %%
k_copies = 2

err_mean_array = []
n_array = []
for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=False)
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list2 = []
r2 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list2.append(result.slope)
    r2.append(result.rvalue)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.0026599784908564184
# 1-r = 0.0177720207148806
# 1-r = 0.02946745071137269
# 1-r = 0.07812786964137852
# 1-r = 0.22576630026877897

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.2, 0.8, len(chi_list)))

two_norm_against_n = []
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    h_purities = [2**(n*k_copies/2) for n in n_list]
    two_norm_errs = [err/h for (err,h) in zip(err_mean,h_purities)]
    two_norm_against_n.append(two_norm_errs)
    plt.plot(n_list[:14], two_norm_errs[:14], label=f'$\chi = {chi}$', color=color)
    
plt.ylabel(r'2-norm error')
plt.xlabel('system size') 
plt.title(f"$k={k_copies}$")
plt.yscale('log')
plt.legend()
plt.savefig("pbc_plot1.pdf", format="pdf", bbox_inches="tight")

# %%
log_err = [np.log(l) for l in two_norm_against_n]
decay_list = []
for x,y in zip(n_array, log_err):
    result = linregress(x, y)
    decay_list.append(result.slope)
    print(result.slope)
    print(1+result.rvalue)
    print("")
# Out:
# -0.6292615259817437
# 0.00019065059167133747
#
# -0.6497038732840489
# 0.0002833918269521396
#
# -0.6460306691640958
# 0.0006347216124632515
#
# -0.6500713160848944
# 0.0005854292296982866
#
# -0.6749720858247038
# 0.0002843118315382087

# %%
2*np.log(2)
# Out:
# 1.3862943611198906

# %%
k_copies = 3

err_mean_array = []
n_array = []
for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=False)
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list3 = []
r3 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list3.append(result.slope)
    r3.append(result.rvalue)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.0239810218211427
# 1-r = 0.011883189480109912
# 1-r = 0.0321380648374171
# 1-r = 0.08761215982247628
# 1-r = 0.3954855911114932

# %%
k_copies = 4

err_mean_array = []
n_array = []
for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=False)
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list4 = []
r4 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list4.append(result.slope)
    r4.append(result.rvalue)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.062468282406871856
# 1-r = 0.011361138537477555
# 1-r = 0.03888211998803248
# 1-r = 0.1166952776690462
# 1-r = 0.5396272654851038

# %%
k_copies = 5

err_mean_array = []
n_array = []
for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=False)
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list5 = []
r5 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list5.append(result.slope)
    r5.append(result.rvalue)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.10921975655243765
# 1-r = 0.015297855670118765
# 1-r = 0.05166763447283973
# 1-r = 0.1737485418634317
# 1-r = 0.7037705502400753

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.25, 0.75, 4))

plt.plot(chi_list, slope_list2, '-o', label="$k=2$", color=colors[0], markersize=3) 
plt.plot(chi_list, slope_list3, '-o', label="$k=3$", color=colors[1], markersize=3) 
plt.plot(chi_list, slope_list4, '-o', label="$k=4$", color=colors[2], markersize=3) 
plt.plot(chi_list, slope_list5, '-o', label="$k=5$", color=colors[3], markersize=3) 
plt.plot(np.array(chi_list), 1/(np.array(chi_list)**2), '--', label=r"$1/\chi^2$", color='k')
plt.ylabel(r'decay rate')
plt.xlabel(r'bond dimension')
plt.yscale('log')
plt.xscale('log')

legend_elements = [
    plt.Line2D([0], [0], color=colors[0], marker='o', linestyle='-', label='$k=2$'),
    plt.Line2D([0], [0], color=colors[1], marker='o', linestyle='-', label='$k=3$'),
    plt.Line2D([0], [0], color=colors[2], marker='o', linestyle='-', label='$k=4$'),
    plt.Line2D([0], [0], color=colors[3], marker='o', linestyle='-', label='$k=5$'),
    plt.Line2D([0], [0], color='k', marker=None, linestyle='--', label=r"$1/\chi^2$")
]

plt.legend(handles=legend_elements, loc="upper center", ncol=5, bbox_to_anchor=(0.5, 1.3))
plt.savefig("pbc_plot2.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# ## TI

# %%
chi_list = [4,8,10,12,14,16]

data_array = []
for chi in chi_list:
    with open(f"ti_{chi}.pickle", "rb") as f: 
        data_array.append(pickle.load(f))

# %%
k_copies = 2

err_mean_array = []
n_array = []
for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=True)
    err_mean_array.append(err_mean)
    n_array.append(n_list)

# %%
with open("translation_invariant_shivan.pickle", 'wb') as f: 
    pickle.dump((err_mean_array, n_array), f)

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.2, 0.8, len(chi_list)))

two_norm_err_list = []
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    h_purities = [haar_purity(n, k_copies, ti=True) for n in n_list]
    two_norm_errs = [err*h for (err,h) in zip(err_mean,h_purities)]
    plt.plot(n_list, two_norm_errs, label=f'$\chi = {chi}$', color=color)
    two_norm_err_list.append(two_norm_errs)
    
plt.ylabel(r'2-norm error')
plt.xlabel('system size') 
plt.title(f"$k={k_copies}$")
plt.yscale('log')
plt.legend()
plt.savefig("ti_plot1.pdf", format="pdf", bbox_inches="tight")



log_err = [np.log(l) for l in two_norm_err_list]
decay_list2 = []
for x,y in zip(n_array, log_err):
    result = linregress(x, y)
    decay_list2.append(result.slope)
    print(result.slope)
    print(1+result.rvalue)
    print("")
# Out:
# -0.7681073212072924
# 0.00046101757986483083
#
# -0.9536836909670827
# 0.0011069972683633855
#
# -0.9970567857728836
# 0.0018229509569938074
#
# -1.0548011429066229
# 0.0013473483092634186
#
# -1.0974737530105148
# 0.0014149690457541109
#
# -1.1136686691973765
# 0.001547276079519988

# %%
k_copies = 3

err_mean_array = []
n_array = []
for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=True)
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
two_norm_err_list = []
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    h_purities = [haar_purity(n, k_copies, ti=True) for n in n_list]
    two_norm_errs = [err*h for (err,h) in zip(err_mean,h_purities)]
    two_norm_err_list.append(two_norm_errs)
    
log_err = [np.log(l) for l in two_norm_err_list]
decay_list3 = []
for x,y in zip(n_array, log_err):
    result = linregress(x, y)
    decay_list3.append(result.slope)
    print(result.slope)
    print(1+result.rvalue)
    print("")
# Out:
# -1.094581763036232
# 0.00039311085074866803
#
# -1.3892719176815491
# 0.0009471715717044304
#
# -1.4590877142969867
# 0.001881211166140706
#
# -1.5502976016627044
# 0.001282832327681227
#
# -1.6370406570267682
# 0.0014239866386963618
#
# -1.6835193591057773
# 0.0016157351677413834

# %%
k_copies = 4

err_mean_array = []
n_array = []
for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=True)
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
two_norm_err_list = []
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    h_purities = [haar_purity(n, k_copies, ti=True) for n in n_list]
    two_norm_errs = [err*h for (err,h) in zip(err_mean,h_purities)]
    two_norm_err_list.append(two_norm_errs)
    
log_err = [np.log(l) for l in two_norm_err_list]
decay_list4 = []
for x,y in zip(n_array, log_err):
    result = linregress(x, y)
    decay_list4.append(result.slope)
    print(result.slope)
    print(1+result.rvalue)
    print("")
# Out:
# -1.4119240076008366
# 0.0005463083322839735
#
# -1.8140641068983212
# 0.0011968250405651748
#
# -1.9135493492392825
# 0.0019350641299091809
#
# -2.031621447080983
# 0.0014582888037547592
#
# -2.1557298275407235
# 0.0016570203482023649
#
# -2.2348765940789725
# 0.0018007592670978845

# %%
k_copies = 5

err_mean_array = []
n_array = []
for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=True)
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
two_norm_err_list = []
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    h_purities = [haar_purity(n, k_copies, ti=True) for n in n_list]
    two_norm_errs = [err*h for (err,h) in zip(err_mean,h_purities)]
    two_norm_err_list.append(two_norm_errs)
    
log_err = [np.log(l) for l in two_norm_err_list]
decay_list5 = []
for x,y in zip(n_array, log_err):
    result = linregress(x, y)
    decay_list5.append(result.slope)
    print(result.slope)
    print(1+result.rvalue)
    print("")
# Out:
# -1.7269048826766136
# 0.0007835615153287678
#
# -2.235433535161878
# 0.0014908080261861745
#
# -2.367282382897817
# 0.0019799532770203854
#
# -2.509862127283283
# 0.0016394325574999868
#
# -2.6631461834058556
# 0.001870802474601918
#
# -2.7745238657291935
# 0.0021589817025746694

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.25, 0.75, 4))

plt.plot(chi_list, 2*np.log(2) + np.array(decay_list2), '-o', label="$k=2$", color=colors[0], markersize=3) 
plt.plot(chi_list, 3*np.log(2) + np.array(decay_list3), '-o', label="$k=3$", color=colors[1], markersize=3) 
plt.plot(chi_list, 4*np.log(2) + np.array(decay_list4), '-o', label="$k=4$", color=colors[2], markersize=3) 
plt.plot(chi_list, 5*np.log(2) + np.array(decay_list5), '-o', label="$k=5$", color=colors[3], markersize=3) 

ax.plot(np.array(chi_list), 1/(np.array(chi_list)**0.59), '--', label=r"$1/\chi^{0.6}$", color='k')
plt.ylabel(r'decay rate')
plt.xlabel(r'bond dimension')
plt.yscale('log')
plt.xscale('log')

legend_elements = [
    plt.Line2D([0], [0], color=colors[0], marker='o', linestyle='-', label='$k=2$'),
    plt.Line2D([0], [0], color=colors[1], marker='o', linestyle='-', label='$k=3$'),
    plt.Line2D([0], [0], color=colors[2], marker='o', linestyle='-', label='$k=4$'),
    plt.Line2D([0], [0], color=colors[3], marker='o', linestyle='-', label='$k=5$'),
    plt.Line2D([0], [0], color='k', marker=None, linestyle='--', label=r"$1/\chi^{0.6}$")
]

plt.legend(handles=legend_elements, loc="upper center", ncol=5, bbox_to_anchor=(0.5, 1.3))
plt.savefig("ti_plot2.pdf", format="pdf", bbox_inches="tight")

# %%
result = linregress(chi_list, 2*np.log(2) + np.array(decay_list))
result.slope, np.abs(result.rvalue)
# Out:
# (-0.02866754030521923, 0.9712367628012668)

# %%
result = linregress(np.log(chi_list), np.log(2*np.log(2) + np.array(decay_list)))
result.slope, result.rvalue
# Out:
# (-0.5991322848194393, -0.9924512274311718)

# %%
2/0.6
# Out:
# 3.3333333333333335

# %% [markdown]
# # Run Oct 23rd

# %% [markdown]
# ## Uniform

# %%
chi_list = [8,10,12,14,16]

data_array = []
for chi in chi_list:
    with open(f"open_uniform_1.0_{chi}.pickle", "rb") as f: 
        data_array.append(pickle.load(f))

# %%
with open("uniform_shivan.pickle", 'wb') as f: 
    pickle.dump((err_mean_array, n_array), f)

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.1, 0.9, len(chi_list)))

err_mean_array = []
n_array = []
k_copies = 2  

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    plt.plot(n_list, err_mean, label=f'$\chi$ = {chi}', color=color)
#plt.legend()
plt.ylabel(r'upper bound on 1-norm error')
plt.xlabel('system size') 
plt.title(f"$k={k_copies}$")
plt.savefig("uniform_plot1.pdf", format="pdf", bbox_inches="tight")

# %%
err_mean_array = []
n_array = []
k_copies = 2

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)

slope_list2 = []
intercept_list2 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list2.append(result.slope)
    intercept_list2.append(result.intercept)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.009911211791855057
# 1-r = 0.028461965386747612
# 1-r = 0.06457387107795431
# 1-r = 0.08226013179023661
# 1-r = 0.10339285713723778

# %%
err_mean_array = []
n_array = []
k_copies = 3

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list3 = []
intercept_list3 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list3.append(result.slope)
    intercept_list3.append(result.intercept)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.008226864165848391
# 1-r = 0.037581652630259366
# 1-r = 0.05420564814220519
# 1-r = 0.07585365807619959
# 1-r = 0.10728592229782397

# %%
err_mean_array = []
n_array = []
k_copies = 4

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list4 = []
intercept_list4 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list4.append(result.slope)
    intercept_list4.append(result.intercept)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.02384160424734072
# 1-r = 0.1161554025492133
# 1-r = 0.06270961870072433
# 1-r = 0.0843180561929221
# 1-r = 0.2431446137182921

# %%
err_mean_array = []
n_array = []
k_copies = 5

for chi,data in zip(chi_list, data_array): 
    n_list = [4+2*i for i in range(len(data))]
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]))
    err_mean_array.append(err_mean)
    n_array.append(n_list)
    
slope_list5 = []
intercept_list5 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list5.append(result.slope)
    intercept_list5.append(result.intercept)
    print(f'1-r = {1-result.rvalue}')
# Out:
# 1-r = 0.06472842844673288
# 1-r = 0.2358029954255655
# 1-r = 0.08559349318157727
# 1-r = 0.11281874617645249
# 1-r = 0.5311237219547954

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.25, 0.75, 4))

plt.plot(np.array(chi_list), slope_list2, label='$k=2$', color=colors[0])
plt.plot(np.array(chi_list), slope_list3, label='$k=3$', color=colors[1])
plt.plot(np.array(chi_list), slope_list4, label='$k=4$', color=colors[2])
plt.plot(np.array(chi_list), slope_list5, label='$k=5$', color=colors[3])
plt.plot(np.array(chi_list), 1/(np.array(chi_list)**2), '--', label=r"$1/\chi^2$", color='k')
plt.yscale('log')
plt.xscale('log')
plt.ylabel(r'$f(\chi)$')
plt.xlabel(r'$\chi$')

plt.legend()
plt.savefig("obc_plot2.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# # Run Oct 28th

# %%
with open("p_10_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp = pickle.load(f)

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.25, 0.75, 4))

ax.plot(chi_list, means, '-o', markersize=3, color=colors[1], label='RMPS purity')
ax.fill_between(chi_list, 
                 means - 2*bars,  
                 means + 2*bars,  
                 alpha=0.4,     
                 color=colors[1])
ax.axhline(hp, linestyle='--', color=colors[-1], label='Haar purity')

ax.set_xticks(np.arange(2,17,2))
plt.xlabel('bond dimension')
plt.ylabel('purity')
plt.legend()
plt.yscale('log')
plt.savefig("pbc_plot0.pdf", format="pdf", bbox_inches="tight")

# %%
with open("o_10_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp = pickle.load(f)
    
means = np.array(means)
bars = np.array(means)

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.25, 0.75, 4))

plt.plot(chi_list, means, '-o', markersize=3, color=colors[1], label='RMPS purity')
plt.fill_between(chi_list, 
                 means - 0.5*bars,  
                 means + 0.5*bars,  
                 alpha=0.4,     
                 color=colors[1])
plt.axhline(hp, linestyle='--', color=colors[-1], label='Haar purity')
ax.set_xticks(np.arange(2,17,2))
plt.xlabel('bond dimension')
plt.ylabel('purity')
#plt.title(r'periodic boundaries, isometric distribution, $k$ = 2')
plt.legend()
plt.yscale('log')
plt.savefig("obc_plot0.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# # Run Oct 29th

# %%
with open("p_4_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp4 = pickle.load(f)
    
means4 = np.array(means)
bars4 = np.array(bars)

with open("p_6_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp6 = pickle.load(f)
    
means6 = np.array(means)
bars6 = np.array(bars)

with open("p_8_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp8 = pickle.load(f)
    
means8 = np.array(means)
bars8 = np.array(bars)

with open("p_10_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp10 = pickle.load(f)
    
means10 = np.array(means)
bars10 = np.array(bars)

with open("p_12_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp12 = pickle.load(f)
    
means12 = np.array(means)
bars12 = np.array(bars)

with open("p_14_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp14 = pickle.load(f)
    
means14 = np.array(means)
bars104 = np.array(bars)

with open("p_18_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp18 = pickle.load(f)
    
means18 = np.array(means)
bars18 = np.array(bars)

with open("p_20_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp20 = pickle.load(f)
    
means20 = np.array(means)
bars20 = np.array(bars)

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.25, 0.75, 4))

ax.plot(chi_list, means, '-o', markersize=3, color=colors[1], label='RMPS purity')
ax.fill_between(chi_list, 
                 means20 - 2*bars20,  
                 means20 + 2*bars20,  
                 alpha=0.4,     
                 color=colors[1])
ax.axhline(hp, linestyle='--', color=colors[-1], label='Haar purity')

ax.set_xticks(np.arange(2,21,2))
plt.xlabel('bond dimension')
plt.ylabel('2-copy purity')
plt.legend()
plt.yscale('log')
plt.savefig("pbc_plot0.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# # Run Oct 30th

# %%
with open("t_20_purity.pickle", "rb") as f: 
    chi_list, means, bars, hp20 = pickle.load(f)
    
means20 = np.array(means)
bars20 = np.array(bars)

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.25, 0.75, 4))

ax.plot(chi_list, means, '-o', markersize=3, color=colors[1], label='RMPS purity')
ax.fill_between(chi_list, 
                 means20 - 2*bars20,  
                 means20 + 2*bars20,  
                 alpha=0.4,     
                 color=colors[1])
ax.axhline(hp, linestyle='--', color=colors[-1], label='Haar purity')

ax.set_xticks(np.arange(2,21,2))
plt.xlabel('bond dimension')
plt.ylabel('2-copy purity')
plt.legend()
plt.yscale('log')
plt.savefig("ti_plot0.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# # Run Nov 22nd

# %%
chi_list = [4,6,8,10,12,16,20,24,28,32]

data_list = []
for chi in chi_list:
    with open(f"p_{chi}.pickle", "rb") as f: 
        data = np.array(list(pickle.load(f).values()))
        data_list.append(data)

# %%
for data in data_list: 
    print(type(data))
    print(data.shape) 
    print(len(data[0]))
# Out:
# <class 'numpy.ndarray'>
# (49, 100000)
# 100000
# <class 'numpy.ndarray'>
# (49, 100000)
# 100000
# <class 'numpy.ndarray'>
# (37, 100000)
# 100000
# <class 'numpy.ndarray'>
# (24, 100000)
# 100000
# <class 'numpy.ndarray'>
# (23, 100000)
# 100000
# <class 'numpy.ndarray'>
# (17, 100000)
# 100000
# <class 'numpy.ndarray'>
# (10, 100000)
# 100000
# <class 'numpy.ndarray'>
# (4, 100000)
# 100000
# <class 'numpy.ndarray'>
# (2, 100000)
# 100000
# <class 'numpy.ndarray'>
# (1, 100000)
# 100000

# %%
n_list = np.arange(4,101,2)

k_copies = 2

err_mean_array = []
for chi,data in zip(chi_list, data_list): 
    err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=False)
    err_mean_array.append(err_mean)
    
slope_list2 = []
r2 = []
for err_mean, n_list in zip(err_mean_array, n_array):
    result = linregress(n_list, err_mean)
    slope_list2.append(result.slope)
    r2.append(result.rvalue)
    print(f'1-r = {1-result.rvalue}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 7
#       5 err_mean_array = []
#       6 for chi,data in zip(chi_list, data_list):
# ----> 7     err_mean, _, n_list = process_data(data, n_list, k_copies, batch_size=len(data[0]), ti=False)
#       8     err_mean_array.append(err_mean)
#      10 slope_list2 = []
#
# Cell In[2], line 13, in process_data(data, n_list, k_copies, batch_size, ti)
#      11 batches = [data[i,j*batch_size:(j+1)*batch_size] for j in range(num_batches)]
#      12 purities = [samples_to_purity(batch, k_copies) for batch in batches]
# ---> 13 diff = np.array([p-h_purity[i] for p in purities])
#      14 if np.all(diff > 0.0):
#      15     one_err = np.sqrt(diff)
#
# Cell In[2], line 13, in <listcomp>(.0)
#      11 batches = [data[i,j*batch_size:(j+1)*batch_size] for j in range(num_batches)]
#      12 purities = [samples_to_purity(batch, k_copies) for batch in batches]
# ---> 13 diff = np.array([p-h_purity[i] for p in purities])
#      14 if np.all(diff > 0.0):
#      15     one_err = np.sqrt(diff)
#
# IndexError: list index out of range

# %%
set_style()
fig, ax = plt.subplots(figsize=(3.2,2))
colors = plt.cm.plasma(np.linspace(0.2, 0.8, len(chi_list)))

two_norm_against_n = []
for chi, err_mean, n_list, color in zip(chi_list, err_mean_array, n_array, colors):
    h_purities = [2**(n*k_copies/2) for n in n_list]
    two_norm_errs = [err/h for (err,h) in zip(err_mean,h_purities)]
    two_norm_against_n.append(two_norm_errs)
    plt.plot(n_list[:14], two_norm_errs[:14], label=f'$\chi = {chi}$', color=color)
    
plt.ylabel(r'2-norm error')
plt.xlabel('system size') 
plt.title(f"$k={k_copies}$")
plt.yscale('log')
plt.legend()
#plt.savefig("pbc_plot1.pdf", format="pdf", bbox_inches="tight")

# %%
type(data_list[0])
# Out:
# numpy.ndarray

# %%
process_data(data, n_list, k_copies, batch_size=1000, ti=False)
